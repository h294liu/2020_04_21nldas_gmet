# %%
#!/usr/bin/env python
# coding: utf-8

# This script is used to compare ensemble outputs with NLDAS data
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import xarray as xr
import datetime

# %%
# file = '/glade/u/home/hongli/scratch/2020_04_21nldas_gmet/test_uniform_perturb/08887grids/gmet_regr/regress_ts.2013.nc'
file = '/glade/u/home/hongli/scratch/2020_04_21nldas_gmet/data/nldas_daily_utc_convert/NLDAS_1987.nc'
f=xr.open_dataset(file)
time = f['time'].values[:]
t_mean = f['t_mean'].values[:]

file = '/glade/u/home/hongli/scratch/2020_04_21nldas_gmet/data/nldas_daily_utc_convert/NLDAS_2016.nc'
f=xr.open_dataset(file)
time_2016 = f['time'].values[:]
t_mean_2016 = f['t_mean'].values[:]

file = '/glade/u/home/hongli/scratch/2020_04_21nldas_gmet/data/nldas_daily_utc_convert/NLDAS_2019.nc'
f=xr.open_dataset(file)
time_2019 = f['time'].values[:]
t_mean_2019 = f['t_mean'].values[:]

print('Done')
# Out:
# Done

# %%
file = '/glade/u/home/hongli/scratch/2020_04_21nldas_gmet/data/nldas_daily_utc_convert/NLDAS_2016.nc'
f=xr.open_dataset(file)
time = f['time'].values[:]
t_range_nldas = f['t_range'].values[:]

file = '/glade/p/ral/hap/anewman/conus_v1p2/eighth/v2_landmask/conus_daily_eighth_20160101_20161231_099.nc4'
f=xr.open_dataset(file)
time = f['time'].values[:]
t_range_stn = f['t_range'].values[:]

print('Done')
# Out:
# Done

# %%
root_dir ='/glade/u/home/hongli/scratch/2020_04_21nldas_gmet/test_uniform_perturb/08884grids/gmet_ens_bc'
ens_num=1 #10 #100
for mb in range(ens_num):
    file = os.path.join(root_dir,'ens_forc.2016.%03d.nc'%(mb+1))
    f=xr.open_dataset(file)
    time = f['time'].values[:]
    t_range = f['t_range'].values[:]
    
    t_range_min = np.nanmin(t_range)
    if t_range_min<0:
        print(mb+1)
print('Done')
# Out:
# 1
# Done

# %%
print(np.nanmin(t_range),np.nanmax(t_range),np.nanmean(t_range),np.nanmedian(t_range))
print(np.nanmin(t_range_nldas),np.nanmax(t_range_nldas),np.nanmean(t_range_nldas),np.nanmedian(t_range_nldas))
# Out:
# -8.788226 35.232365 9.60836 9.731602
# 0.07998657 39.880005 9.532134 9.679993

# %%
# read original nldas tmin and tmax
file = '/glade/u/home/hongli/scratch/2020_04_21nldas_gmet/test_uniform_perturb/08884grids/gmet_ens_bc/bias_corr.2016.001.nc.bk'
f=xr.open_dataset(file)
time = f['time'].values[:]
t_range = f['t_range'].values[:]
t_range_bc = f['t_range_bc'].values[:]
t_range_origin = f['t_range_origin'].values[:]
print('Done')
# Out:
# Done

# %%
np.where((t_range!=t_range_origin) & (~np.isnan(t_range_origin)))
# Out:
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))

# %%
t,i,j=365,223,364
t_range[t,i,j],t_range_bc[t,i,j],
# Out:
# (nan, nan)

# %%
plt.imshow(t_range[0,:,:]!=t_range_origin[0,:,:])

# %%
plt.imshow(tair_range[100,:,:])

# %%
np.shape(t_range_stn)
# Out:
# (366, 224, 464)

# %%
plt.plot(np.arange(len(t_range_stn[:,100,100])),t_range_stn[:,100,100],t_range_nldas[:,100,100])

# %%
file = '/glade/u/home/hongli/scratch/2020_08_17stn_gmet/stn_gmet/gmet_regr/regress_ts.2013.nc'
f=xr.open_dataset(file)
stn_time = f['time'].values[:]
stn_trange_2 = f['trange_2'].values[:]
stn_trange_error_2 = f['trange_error_2'].values[:]
plt.imshow(stn_trange_error_2[0,:,:])

# %%
plt.imshow(stn_trange_2[0,:,:])

# %%
plt.hist(stn_trange_error_2[0,:,:])
print(np.nanmean(stn_trange_error_2[0,:,:]),np.nanstd(stn_trange_error_2[0,:,:]))
# Out:
# 0.9287481326245693 0.8232940723202413
