# %%
#!/usr/bin/env python
# coding: utf-8

# This script is used to compare ensemble outputs with NLDAS data
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import xarray as xr
import datetime

# %%
# file = '/glade/u/home/hongli/scratch/2020_04_21nldas_gmet/test_uniform_perturb/08887grids/gmet_regr/regress_ts.2013.nc'
file = '/glade/u/home/hongli/scratch/2020_04_21nldas_gmet/data/nldas_topo/conus_ens_grid_eighth_deg_v1p1.nc'
f=xr.open_dataset(file)
elev_stn = f['elev'].values[:]

file = '/glade/u/home/hongli/scratch/2020_04_21nldas_gmet/data/nldas_topo/conus_ens_grid_eighth.nc'
f=xr.open_dataset(file)
elev = f['elev'].values[:]

print('Done')
# Out:
# Done

# %%
plt.imshow(elev_stn!=elev)

# %%
plt.imshow(np.absolute(elev_dif)>5,origin='lower')
# Out:
# <ipython-input-17-53e69906785f>:1: RuntimeWarning: invalid value encountered in greater
#   plt.imshow(np.absolute(elev_dif)>5,origin='lower')

# %%
elev_dif=elev-elev_stn
np.nanmax(elev_dif),np.nanmin(elev_dif),np.nanargmax(elev_dif),np.nanargmin(elev_dif)
# Out:
# (409.61737060546875, -659.0372206604004, 94656, 40858)

# %%
np.savetxt('elevation_difference.txt',elev_dif,delimiter=',',fmt='%.6f')

# %%
file = '/glade/u/home/hongli/scratch/2020_04_21nldas_gmet/test_uniform_perturb/08884grids/gmet_ens_bc/ens_forc.2016.001.nc'
f=xr.open_dataset(file)
time = f['time'].values[:]
t_range = f['t_range'].values[:]

# %%
t,i,j=365,133,7
t_range[t,i,j],t_range_bc[t,i,j],t_range_origin[t,i,j],
# Out:
# (2.0, -0.0819664, 2.0)

# %%
np.where(t_range<0)
# Out:
# <ipython-input-9-293a94fb1bb7>:1: RuntimeWarning: invalid value encountered in less
#   np.where(t_range<0)
# (array([], dtype=int64), array([], dtype=int64), array([], dtype=int64))

# %%
plt.imshow(t_range[100,:,:])

# %%
np.shape(t_range_stn)
# Out:
# (366, 224, 464)

# %%
plt.plot(np.arange(len(t_range_stn[:,100,100])),t_range_stn[:,100,100],t_range_nldas[:,100,100])

# %%
file = '/glade/u/home/hongli/scratch/2020_08_17stn_gmet/stn_gmet/gmet_regr/regress_ts.2013.nc'
f=xr.open_dataset(file)
stn_time = f['time'].values[:]
stn_trange_2 = f['trange_2'].values[:]
stn_trange_error_2 = f['trange_error_2'].values[:]
plt.imshow(stn_trange_error_2[0,:,:])

# %%
plt.imshow(stn_trange_2[0,:,:])

# %%
plt.hist(stn_trange_error_2[0,:,:])
print(np.nanmean(stn_trange_error_2[0,:,:]),np.nanstd(stn_trange_error_2[0,:,:]))
# Out:
# 0.9287481326245693 0.8232940723202413
