# %%
import numpy as np
import os

from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
from pyproj import Proj
import xarray as xr
from itertools import chain
       
def plot_basemap(llcrnrlon,llcrnrlat,urcrnrlon,urcrnrlat,ax,lat_0,lon_0):

    m = Basemap(llcrnrlon,llcrnrlat,urcrnrlon,urcrnrlat,resolution='l',projection='cyl', ax=ax)   

    m.drawstates(linewidth=1, linestyle='solid', color='grey')
    m.drawcountries(linewidth=1, linestyle='solid', color='k')
    m.drawcoastlines(linewidth=.75, linestyle='solid', color='k')
   
    # lat and lon with lables
    m.drawparallels(np.arange(np.floor(llcrnrlat),np.ceil(urcrnrlat),1),labels=[True,False,False,False],dashes=[1,1], fontsize='small') # Draw parallels (latitude lines) for values (in degrees).
    m.drawmeridians(np.arange(np.floor(llcrnrlon),np.ceil(urcrnrlon),1),labels=[False,False,False,True],dashes=[1,1], fontsize='small') # Draw meridians (longitude lines). Label [left, right, top, bottom]
    
    # draw a shaded-relief image
    m.shadedrelief(scale=0.5)
    
    # lats and longs are returned as a dictionary
    dy = 1/8.0
    dx = 1/8.0
    lats = m.drawparallels(np.arange(llcrnrlat,urcrnrlat,dy),labels=[False,False,False,False],dashes=[0.5,0.5]) 
    lons = m.drawmeridians(np.arange(llcrnrlon,urcrnrlon,dx),labels=[False,False,False,False],dashes=[0.5,0.5]) 

    lat_lines = chain(*(tup[1][0] for tup in lats.items()))
    lon_lines = chain(*(tup[1][0] for tup in lons.items()))
    all_lines = chain(lat_lines, lon_lines)
    
    # cycle through these lines and set the desired style
    for line in all_lines:
        line.set(linestyle='-', alpha=0.3, color='grey')
    return m

# main script
root_dir = '/glade/u/home/hongli/scratch/2020_04_21nldas_gmet/scripts'
ofolder = 'step16_debug_nearet_stn_character'
if not os.path.exists(os.path.join(root_dir,ofolder)):
    os.makedirs(os.path.join(root_dir,ofolder))
ofolder_subs = ['invalid','valid']
for ofolder_sub in ofolder_subs:
    if not os.path.exists(os.path.join(root_dir,ofolder,ofolder_sub)):
        os.makedirs(os.path.join(root_dir,ofolder,ofolder_sub))    
  
# ----plot nearest stn----
print('---plot nearest stn---')
# read all grids' info
grid_list = np.loadtxt(os.path.join(root_dir,ofolder,'GridID_StartLine.txt'),delimiter=',',usecols=[0],skiprows=1)
invalid_grid_list = os.listdir(os.path.join(root_dir,ofolder, 'invalid'))
valid_grid_list = os.listdir(os.path.join(root_dir,ofolder, 'valid'))

# method 1: plot all grids' nearest stns
# # for i in range(len(grids_loc)-1):
# for grid_id in invalid_grids:
#     if grid_id in grid_list:
#         print('grid_id '+str(grid_id))

#         grid_file = str(grid_id)+'_grid.txt'
#         if grid_file in invalid_grid_list:
#             ofolder_sub = 'invalid'
#         else:
#             ofolder_sub = 'valid'

# # method 2: only plot invalid grids' neareast stns
# invalid_grids=[int(file.split('_')[0]) for file in invalid_grid_list if '_grid.txt' in file] #only plot invalid grids
# for grid_id in invalid_grids:
#     if grid_id in grid_list:
        
#         print('grid_id '+str(grid_id))

#         grid_file = str(grid_id)+'_grid.txt'
#         ofolder_sub = 'invalid'
            
#         # grid info
#         data = np.loadtxt(os.path.join(root_dir,ofolder, ofolder_sub, grid_file),delimiter=',',skiprows=1)
#         grid_id = int(data[0])
#         grid_lat = data[1]
#         grid_lon = data[2]
#         label = int(data[3])
#         grid_row = int(data[4])
#         grid_col = int(data[5])

#         # station info
#         x_red_file = str(grid_id)+'_nearest_stn.txt'
#         x_red = np.loadtxt(os.path.join(root_dir,ofolder, ofolder_sub, x_red_file),
#                            delimiter=',',usecols=[2,3],skiprows=1)    

#         # plot
#         fig, ax = plt.subplots()
#         fig.set_figwidth(4.5*2) 
#         fig.set_figheight(4.5*2)

#         stn_lats = x_red[:,0]
#         stn_lons = x_red[:,1]
#         llcrnrlon = np.amin(stn_lons)-(2/8.0)
#         llcrnrlat = np.amin(stn_lats)-(2/8.0)
#         urcrnrlon = np.amax(stn_lons)+(2/8.0)
#         urcrnrlat = np.amax(stn_lats)+(2/8.0)
#         lat_0 = grid_lat
#         lon_0 = grid_lon
#         m = plot_basemap(llcrnrlon,llcrnrlat,urcrnrlon,urcrnrlat,ax,lat_0,lon_0) # plot Basemap 
#         m.scatter(stn_lons, stn_lats, marker = 'o', color='r', zorder=2, alpha=0.8, label='station')
#         m.scatter(grid_lon, grid_lat, marker = '^', color='b', zorder=2, alpha=0.8, label='grid')

#         plt.legend(loc='upper right')
#         title_str = 'GridID '+str(grid_id) + ' (Row = '+str(grid_row)+', Col = '+str(grid_col)+')'
#         plt.title(title_str, fontsize='small', fontweight='semibold')

#         fig.tight_layout()
#         ofile = str(grid_id)+'_nearest_stn.png'
#         fig.savefig(os.path.join(root_dir,ofolder, ofolder_sub, ofile), dpi=100)
#         plt.close(fig)   

valid_grids=[int(file.split('_')[0]) for file in valid_grid_list if '_grid.txt' in file] #only plot invalid grids
for grid_id in valid_grids[10000:12000]:
    if grid_id in grid_list:
        
        print('grid_id '+str(grid_id))

        grid_file = str(grid_id)+'_grid.txt'
        ofolder_sub = 'valid'
            
        # grid info
        data = np.loadtxt(os.path.join(root_dir,ofolder, ofolder_sub, grid_file),delimiter=',',skiprows=1)
        grid_id = int(data[0])
        grid_lat = data[1]
        grid_lon = data[2]
        label = int(data[3])
        grid_row = int(data[4])
        grid_col = int(data[5])

        # station info
        x_red_file = str(grid_id)+'_nearest_stn.txt'
        x_red = np.loadtxt(os.path.join(root_dir,ofolder, ofolder_sub, x_red_file),
                           delimiter=',',usecols=[2,3],skiprows=1)    

        # plot
        fig, ax = plt.subplots()
        fig.set_figwidth(4.5*2) 
        fig.set_figheight(4.5*2)

        stn_lats = x_red[:,0]
        stn_lons = x_red[:,1]
        llcrnrlon = np.amin(stn_lons)-(2/8.0)
        llcrnrlat = np.amin(stn_lats)-(2/8.0)
        urcrnrlon = np.amax(stn_lons)+(2/8.0)
        urcrnrlat = np.amax(stn_lats)+(2/8.0)
        lat_0 = grid_lat
        lon_0 = grid_lon
        m = plot_basemap(llcrnrlon,llcrnrlat,urcrnrlon,urcrnrlat,ax,lat_0,lon_0) # plot Basemap 
        m.scatter(stn_lons, stn_lats, marker = 'o', color='r', zorder=2, alpha=0.8, label='station')
        m.scatter(grid_lon, grid_lat, marker = '^', color='b', zorder=2, alpha=0.8, label='grid')

        plt.legend(loc='upper right')
        title_str = 'GridID '+str(grid_id) + ' (Row = '+str(grid_row)+', Col = '+str(grid_col)+')'
        plt.title(title_str, fontsize='small', fontweight='semibold')

        fig.tight_layout()
        ofile = str(grid_id)+'_nearest_stn.png'
        fig.savefig(os.path.join(root_dir,ofolder, ofolder_sub, ofile), dpi=100)
        plt.close(fig)  
print('Done')
# Out:
# ---plot nearest stn---
# grid_id 18679
# /glade/u/home/hongli/tools/miniconda/ENTER/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   if sys.path[0] == '':
# /glade/u/home/hongli/tools/miniconda/ENTER/lib/python3.7/site-packages/ipykernel_launcher.py:14: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#
# /glade/u/home/hongli/tools/miniconda/ENTER/lib/python3.7/site-packages/ipykernel_launcher.py:15: MatplotlibDeprecationWarning:
# The dedent function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use inspect.cleandoc instead.
#   from ipykernel import kernelapp as app
# grid_id 19791
# grid_id 9418
# grid_id 5720
# grid_id 5784
# grid_id 17973
# grid_id 6407
# grid_id 29934
# grid_id 19225
# grid_id 2235
# grid_id 13153
# grid_id 7612
# grid_id 3431
# grid_id 26252
# grid_id 21598
# grid_id 18692
# grid_id 23848
# grid_id 16113
# grid_id 25841
# grid_id 6842
# grid_id 27914
# grid_id 23052
# grid_id 9937
# grid_id 21524
# grid_id 22036
# grid_id 29841
# grid_id 20687
# grid_id 12718
# grid_id 5247
# grid_id 28932
# grid_id 114
# grid_id 5742
# grid_id 21953
# grid_id 22451
# grid_id 13218
# grid_id 16363
# grid_id 19248
# grid_id 4355
# grid_id 22044
# grid_id 24875
# grid_id 21965
# grid_id 19776
# grid_id 23026
# grid_id 25636
# grid_id 3419
# grid_id 29897
# grid_id 19831
# grid_id 19345
# grid_id 16926
# grid_id 25157
# grid_id 23982
# grid_id 16404
# grid_id 26648
# grid_id 18197
# grid_id 15009
# grid_id 4787
# grid_id 23772
# grid_id 21206
# grid_id 28832
# grid_id 20278
# grid_id 11348
# grid_id 21507
# grid_id 22941
# grid_id 27467
# grid_id 7623
# grid_id 17869
# grid_id 7168
# grid_id 28569
# grid_id 23388
# grid_id 13213
# grid_id 19293
# grid_id 22079
# grid_id 3815
# grid_id 28152
# grid_id 17381
# grid_id 23437
# grid_id 30012
# grid_id 22487
# grid_id 28400
# grid_id 14940
# grid_id 16884
# grid_id 10403
# grid_id 821
# grid_id 26275
# grid_id 29123
# grid_id 7977
# grid_id 24006
# grid_id 16873
# grid_id 12740
# grid_id 8958
# grid_id 19629
# grid_id 24003
# grid_id 18781
# grid_id 17046
# grid_id 150
# grid_id 25680
# grid_id 16478
# grid_id 649
# grid_id 5210
# grid_id 28491
# grid_id 24680
# grid_id 24866
# grid_id 16947
# grid_id 28992
# grid_id 26265
# grid_id 24372
# grid_id 27569
# grid_id 26138
# grid_id 14006
# grid_id 24829
# grid_id 28880
# grid_id 8965
# grid_id 23878
# grid_id 14948
# grid_id 20999
# grid_id 26147
# grid_id 15662
# grid_id 17827
# grid_id 26181
# grid_id 18743
# grid_id 6840
# grid_id 14028
# grid_id 2038
# grid_id 27163
# grid_id 112
# grid_id 25373
# grid_id 18260
# grid_id 4346
# grid_id 20518
# grid_id 20031
# grid_id 25780
# grid_id 24220
# grid_id 29285
# grid_id 3424
# grid_id 11488
# grid_id 9173
# grid_id 26620
# grid_id 8559
# grid_id 21482
# grid_id 21673
# grid_id 28184
# grid_id 5298
# grid_id 16114
# grid_id 10869
# grid_id 9879
# grid_id 6203
# grid_id 4839
# grid_id 15987
# grid_id 21062
# grid_id 15871
# grid_id 19152
# grid_id 14438
# grid_id 24325
# grid_id 27627
# grid_id 26778
# grid_id 17885
# grid_id 18719
# grid_id 13205
# grid_id 28556
# grid_id 13686
# grid_id 23001
# grid_id 15499
# grid_id 20267
# grid_id 22599
# grid_id 11266
# grid_id 18445
# grid_id 18360
# grid_id 21525
# grid_id 1593
# grid_id 25238
# grid_id 4525
# grid_id 17763
# grid_id 9874
# grid_id 19653
# grid_id 22507
# grid_id 29381
# grid_id 23881
# grid_id 27987
# grid_id 28017
# grid_id 29498
# grid_id 26779
# grid_id 27171
# grid_id 25705
# grid_id 26606
# grid_id 24350
# grid_id 9015
# grid_id 13131
# grid_id 10770
# grid_id 9900
# grid_id 16855
# grid_id 16431
# grid_id 21629
# grid_id 8062
# grid_id 3389
# grid_id 16796
# grid_id 27074
# grid_id 3919
# grid_id 3464
# grid_id 21660
# grid_id 18270
# grid_id 13332
# grid_id 7620
# grid_id 26329
# grid_id 28838
# grid_id 3898
# grid_id 11248
# grid_id 18741
# grid_id 25358
# grid_id 22851
# grid_id 24855
# grid_id 5313
# grid_id 17912
# grid_id 16440
# grid_id 29484
# grid_id 11356
# grid_id 2939
# grid_id 13677
# grid_id 27149
# grid_id 27671
# grid_id 3601
# grid_id 22932
# grid_id 21657
# grid_id 20562
# grid_id 9422
# grid_id 18821
# grid_id 7587
# grid_id 28630
# grid_id 25776
# grid_id 8974
# grid_id 11304
# grid_id 4387
# grid_id 15463
# grid_id 14146
# grid_id 19145
# grid_id 25392
# grid_id 4284
# grid_id 2030
# grid_id 29404
# grid_id 8981
# grid_id 27037
# grid_id 18701
# grid_id 27543
# grid_id 12676
# grid_id 8020
# grid_id 26747
# grid_id 6647
# grid_id 27663
# grid_id 20655
# grid_id 25848
# grid_id 24933
# grid_id 18345
# grid_id 29008
# grid_id 2502
# grid_id 11343
# grid_id 24015
# grid_id 4348
# grid_id 23370
# grid_id 6131
# grid_id 12418
# grid_id 573
# grid_id 8045
# grid_id 2063
# grid_id 24361
# grid_id 16063
# grid_id 18335
# grid_id 29589
# grid_id 24308
# grid_id 12213
# grid_id 3891
# grid_id 14961
# grid_id 11017
# grid_id 4997
# grid_id 9870
# grid_id 24378
# grid_id 20735
# grid_id 24004
# grid_id 2073
# grid_id 7100
# grid_id 23949
# grid_id 6670
# grid_id 8052
# grid_id 17754
# grid_id 3414
# grid_id 28970
# grid_id 21040
# grid_id 25844
# grid_id 26050
# grid_id 13611
# grid_id 23776
# grid_id 27226
# grid_id 4278
# grid_id 18252
# grid_id 19817
# grid_id 27457
# grid_id 29906
# grid_id 14543
# grid_id 15907
# grid_id 7129
# grid_id 11741
# grid_id 23442
# grid_id 15552
# grid_id 26106
# grid_id 20144
# grid_id 16353
# grid_id 18666
# grid_id 10356
# grid_id 24864
# grid_id 15052
# grid_id 27216
# grid_id 27493
# grid_id 15028
# grid_id 20273
# grid_id 2929
# grid_id 26774
# grid_id 17890
# grid_id 23547
# grid_id 19727
# grid_id 27932
# grid_id 19833
# grid_id 16902
# grid_id 21209
# grid_id 24401
# grid_id 23032
# grid_id 2686
# grid_id 1743
# grid_id 5325
# grid_id 19701
# grid_id 23300
# grid_id 5741
# grid_id 10785
# grid_id 381
# grid_id 28912
# grid_id 8935
# grid_id 24754
# grid_id 6391
# grid_id 10334
# grid_id 21958
# grid_id 17516
# grid_id 4522
# grid_id 24937
# grid_id 25830
# grid_id 23415
# grid_id 17329
# grid_id 21675
# grid_id 28628
# grid_id 23055
# grid_id 20224
# grid_id 15402
# grid_id 26259
# grid_id 24312
# grid_id 18773
# grid_id 17501
# grid_id 19612
# grid_id 1544
# grid_id 7169
# grid_id 29774
# grid_id 22057
# grid_id 4835
# grid_id 12195
# grid_id 840
# grid_id 25864
# grid_id 3385
# grid_id 8555
# grid_id 14943
# grid_id 20246
# grid_id 17838
# grid_id 23973
# grid_id 21959
# grid_id 25234
# grid_id 13666
# grid_id 8563
# grid_id 16062
# grid_id 29437
# grid_id 28862
# grid_id 1566
# grid_id 10082
# grid_id 9882
# grid_id 18355
# grid_id 28493
# grid_id 20625
# grid_id 5307
# grid_id 22369
# grid_id 622
# grid_id 7512
# grid_id 22089
# grid_id 23007
# grid_id 18675
# grid_id 6234
# grid_id 17840
# grid_id 7644
# grid_id 14584
# grid_id 3466
# grid_id 29309
# grid_id 23795
# grid_id 25795
# grid_id 7055
# grid_id 18716
# grid_id 27016
# grid_id 26107
# grid_id 8531
# grid_id 27447
# grid_id 24355
# grid_id 2008
# grid_id 22531
# grid_id 20268
# grid_id 28908
# grid_id 18264
# grid_id 24272
# grid_id 3933
# grid_id 21619
# grid_id 16406
# grid_id 15994
# grid_id 26301
# grid_id 5461
# grid_id 20234
# grid_id 22474
# grid_id 21423
# grid_id 19681
# grid_id 4378
# grid_id 24425
# grid_id 28581
# grid_id 1527
# grid_id 29110
# grid_id 24466
# grid_id 4988
# grid_id 29820
# grid_id 11344
# grid_id 3143
# grid_id 19366
# grid_id 12733
# grid_id 10862
# grid_id 2035
# grid_id 24909
# grid_id 21575
# grid_id 20521
# grid_id 8103
# grid_id 19730
# grid_id 17289
# grid_id 27999
# grid_id 21910
# grid_id 24921
# grid_id 29012
# grid_id 28178
# grid_id 26720
# grid_id 13223
# grid_id 29978
# grid_id 21184
# grid_id 21168
# grid_id 20212
# grid_id 12180
# grid_id 29372
# grid_id 28882
# grid_id 17052
# grid_id 15663
# grid_id 1998
# grid_id 29551
# grid_id 205
# grid_id 6156
# grid_id 15989
# grid_id 17512
# grid_id 18690
# grid_id 8239
# grid_id 9467
# grid_id 26526
# grid_id 27126
# grid_id 4390
# grid_id 143
# grid_id 15037
# grid_id 22809
# grid_id 28163
# grid_id 23796
# grid_id 26685
# grid_id 22933
# grid_id 26531
# grid_id 23017
# grid_id 8572
# grid_id 13800
# grid_id 27055
# grid_id 13607
# grid_id 29014
# grid_id 15191
# grid_id 17318
# grid_id 17270
# grid_id 27065
# grid_id 21967
# grid_id 20516
# grid_id 841
# grid_id 29346
# grid_id 19354
# grid_id 26630
# grid_id 21114
# grid_id 19241
# grid_id 23786
# grid_id 28995
# grid_id 15435
# grid_id 9479
# grid_id 27045
# grid_id 6384
# grid_id 19712
# grid_id 23512
# grid_id 24422
# grid_id 5451
# grid_id 28664
# grid_id 12668
# grid_id 13582
# grid_id 670
# grid_id 22097
# grid_id 14118
# grid_id 13099
# grid_id 6868
# grid_id 23937
# grid_id 4815
# grid_id 12228
# grid_id 17343
# grid_id 9476
# grid_id 19656
# grid_id 20701
# grid_id 24245
# grid_id 29128
# grid_id 20628
# grid_id 10760
# grid_id 8073
# grid_id 18833
# grid_id 19187
# grid_id 7133
# grid_id 23012
# grid_id 29300
# grid_id 20288
# grid_id 7319
# grid_id 28410
# grid_id 9962
# grid_id 6713
# grid_id 20765
# grid_id 8038
# grid_id 16916
# grid_id 7161
# grid_id 10096
# grid_id 5263
# grid_id 22467
# grid_id 23416
# grid_id 13189
# grid_id 26127
# grid_id 23495
# grid_id 24687
# grid_id 20665
# grid_id 3608
# grid_id 28403
# grid_id 8693
# grid_id 24376
# grid_id 20127
# grid_id 11310
# grid_id 5201
# grid_id 15012
# grid_id 23994
# grid_id 20146
# grid_id 18640
# grid_id 28002
# grid_id 13615
# grid_id 25292
# grid_id 8515
# grid_id 23469
# grid_id 3861
# grid_id 8979
# grid_id 10829
# grid_id 6140
# grid_id 20496
# grid_id 17283
# grid_id 4340
# grid_id 28133
# grid_id 13116
# grid_id 28161
# grid_id 28644
# grid_id 23888
# grid_id 20592
# grid_id 29362
# grid_id 17277
# grid_id 17053
# grid_id 12735
# grid_id 27958
# grid_id 8989
# grid_id 28915
# grid_id 12236
# grid_id 15979
# grid_id 11275
# grid_id 4345
# grid_id 19337
# grid_id 1089
# grid_id 20545
# grid_id 22869
# grid_id 20072
# grid_id 13338
# grid_id 14073
# grid_id 28886
# grid_id 16013
# grid_id 20748
# grid_id 12678
# grid_id 13200
# grid_id 26777
# grid_id 8983
# grid_id 6183
# grid_id 1967
# grid_id 2915
# grid_id 29090
# grid_id 24237
# grid_id 18793
# grid_id 24474
# grid_id 27047
# grid_id 21487
# grid_id 12867
# grid_id 26756
# grid_id 21163
# grid_id 27520
# grid_id 2507
# grid_id 13673
# grid_id 4810
# grid_id 25248
# grid_id 23412
# grid_id 13341
# grid_id 5269
# grid_id 21887
# grid_id 22145
# grid_id 29326
# grid_id 23859
# grid_id 15071
# grid_id 7527
# grid_id 21909
# grid_id 25823
# grid_id 14489
# grid_id 27224
# grid_id 16476
# grid_id 9933
# grid_id 26669
# grid_id 22048
# grid_id 20155
# grid_id 23880
# grid_id 29096
# grid_id 12658
# grid_id 23405
# grid_id 9964
# grid_id 4740
# grid_id 29052
# grid_id 2940
# grid_id 6211
# grid_id 29976
# grid_id 9943
# grid_id 10305
# grid_id 11298
# grid_id 25859
# grid_id 25276
# grid_id 19654
# grid_id 3006
# grid_id 14275
# grid_id 3141
# grid_id 13120
# grid_id 8439
# grid_id 20489
# grid_id 24403
# grid_id 23387
# grid_id 25125
# grid_id 23928
# grid_id 10759
# grid_id 4072
# grid_id 17797
# grid_id 28996
# grid_id 5448
# grid_id 23372
# grid_id 17738

# %%
grids
# Out:
# [23336,
#  24738,
#  24304,
#  25661,
#  24773,
#  24319,
#  15513,
#  23326,
#  22109,
#  15039,
#  25656,
#  26120,
#  22408,
#  22403,
#  25207,
#  25716,
#  21181,
#  24893,
#  21011,
#  25671,
#  25676,
#  19624,
#  20153,
#  18292,
#  25746,
#  26175,
#  25277,
#  15508,
#  20612,
#  15977,
#  26165,
#  16436,
#  24274,
#  25706,
#  25212,
#  20148,
#  25187,
#  24788,
#  21550,
#  15049,
#  24259,
#  22573,
#  14580,
#  19220,
#  23356,
#  17828,
#  24718,
#  22862,
#  25666,
#  20617,
#  21545,
#  19694,
#  25222,
#  24314,
#  19230,
#  24249,
#  24269,
#  25701,
#  23790,
#  21081,
#  25217,
#  22014,
#  24284,
#  21086,
#  22019,
#  23346,
#  26145,
#  23037,
#  26125,
#  18756,
#  24339,
#  24743,
#  24748,
#  25192,
#  25197,
#  26110,
#  24753,
#  24254,
#  24728,
#  24344,
#  16905,
#  22872,
#  21091,
#  25646,
#  25357,
#  24429,
#  22882,
#  15972,
#  24758,
#  25252,
#  26150,
#  24723,
#  16900,
#  20622,
#  20547,
#  20083,
#  26155,
#  26185,
#  15967,
#  26115,
#  20627,
#  21006,
#  17823,
#  25242,
#  22942,
#  26105,
#  16895,
#  15044,
#  16441,
#  26140,
#  17369,
#  22009,
#  21470,
#  21944,
#  25821,
#  25237,
#  24264,
#  24813,
#  20163,
#  21939,
#  25686,
#  19160,
#  22004,
#  25641,
#  26130,
#  20158,
#  24793,
#  21016,
#  21540,
#  24299,
#  24713,
#  17364,
#  21475,
#  17833,
#  25202,
#  22463,
#  24279,
#  25182,
#  25177,
#  25651,
#  23800,
#  23965,
#  23860,
#  20253,
#  24768,
#  26135,
#  21934,
#  23501,
#  23850,
#  22398]

# %%
grids_loc_extend
# Out:
# array([[ 103.    ,   25.0625, -112.1875,    0.    ,  103.    ],
#        [ 104.    ,   25.0625, -112.0625,    0.    ,  104.    ],
#        [ 105.    ,   25.0625, -111.9375,    0.    ,  105.    ],
#        [ 106.    ,   25.0625, -111.8125,    0.    ,  106.    ],
#        [ 107.    ,   25.0625, -111.6875,    0.    ,  107.    ],
#        [ 108.    ,   25.0625, -111.5625,    0.    ,  108.    ],
#        [ 109.    ,   25.0625, -111.4375,    0.    ,  109.    ],
#        [ 110.    ,   25.0625, -111.3125,    0.    ,  110.    ],
#        [ 111.    ,   25.0625, -111.1875,    0.    ,  111.    ],
#        [ 112.    ,   25.0625, -111.0625,    0.    ,  112.    ],
#        [ 113.    ,   25.0625, -110.9375,    0.    ,  113.    ],
#        [ 114.    ,   25.0625, -110.8125,    0.    ,  114.    ],
#        [ 115.    ,   25.0625, -110.6875,    0.    ,  115.    ],
#        [ 116.    ,   25.0625, -110.5625,    0.    ,  116.    ],
#        [ 134.    ,   25.0625, -108.3125,    0.    ,  134.    ],
#        [ 135.    ,   25.0625, -108.1875,    0.    ,  135.    ],
#        [ 136.    ,   25.0625, -108.0625,    0.    ,  136.    ],
#        [ 137.    ,   25.0625, -107.9375,    0.    ,  137.    ],
#        [ 138.    ,   25.0625, -107.8125,    0.    ,  138.    ],
#        [ 139.    ,   25.0625, -107.6875,    0.    ,  139.    ],
#        [ 140.    ,   25.0625, -107.5625,    0.    ,  140.    ],
#        [ 141.    ,   25.0625, -107.4375,    0.    ,  141.    ],
#        [ 142.    ,   25.0625, -107.3125,    0.    ,  142.    ],
#        [ 143.    ,   25.0625, -107.1875,    0.    ,  143.    ],
#        [ 144.    ,   25.0625, -107.0625,    0.    ,  144.    ],
#        [ 145.    ,   25.0625, -106.9375,    0.    ,  145.    ],
#        [ 146.    ,   25.0625, -106.8125,    0.    ,  146.    ],
#        [ 147.    ,   25.0625, -106.6875,    0.    ,  147.    ],
#        [ 148.    ,   25.0625, -106.5625,    0.    ,  148.    ],
#        [ 149.    ,   25.0625, -106.4375,    0.    ,  149.    ],
#        [ 150.    ,   25.0625, -106.3125,    0.    ,  150.    ],
#        [ 151.    ,   25.0625, -106.1875,    0.    ,  151.    ],
#        [ 152.    ,   25.0625, -106.0625,    0.    ,  152.    ],
#        [ 153.    ,   25.0625, -105.9375,    0.    ,  153.    ],
#        [ 154.    ,   25.0625, -105.8125,    0.    ,  154.    ],
#        [ 155.    ,   25.0625, -105.6875,    0.    ,  155.    ],
#        [ 156.    ,   25.0625, -105.5625,    0.    ,  156.    ],
#        [ 157.    ,   25.0625, -105.4375,    0.    ,  157.    ],
#        [ 158.    ,   25.0625, -105.3125,    0.    ,  158.    ],
#        [ 159.    ,   25.0625, -105.1875,    0.    ,  159.    ],
#        [ 160.    ,   25.0625, -105.0625,    0.    ,  160.    ],
#        [ 161.    ,   25.0625, -104.9375,    0.    ,  161.    ],
#        [ 162.    ,   25.0625, -104.8125,    0.    ,  162.    ],
#        [ 163.    ,   25.0625, -104.6875,    0.    ,  163.    ],
#        [ 164.    ,   25.0625, -104.5625,    0.    ,  164.    ],
#        [ 165.    ,   25.0625, -104.4375,    0.    ,  165.    ],
#        [ 166.    ,   25.0625, -104.3125,    0.    ,  166.    ],
#        [ 167.    ,   25.0625, -104.1875,    0.    ,  167.    ],
#        [ 168.    ,   25.0625, -104.0625,    0.    ,  168.    ],
#        [ 169.    ,   25.0625, -103.9375,    0.    ,  169.    ]])

# %%
tx_red_2.reshape(30,4)
# Out:
# array([[ 1.00000000e+00,  2.50625000e+01, -1.11187500e+02,
#          2.92816711e+02],
#        [ 1.00000000e+00,  2.50625000e+01, -1.07437500e+02,
#          2.08589096e+02],
#        [ 1.00000000e+00,  2.50625000e+01, -1.06187500e+02,
#          2.43743604e+03],
#        [ 1.00000000e+00,  2.50625000e+01, -1.04937500e+02,
#          2.24313696e+03],
#        [ 1.00000000e+00,  3.00625000e+01, -1.07437500e+02,
#          1.52901404e+03],
#        [ 1.00000000e+00,  3.00625000e+01, -1.12437500e+02,
#          5.11484100e+02],
#        [ 1.00000000e+00,  3.13125000e+01, -1.12437500e+02,
#          6.23042297e+02],
#        [ 1.00000000e+00,  2.88125000e+01, -1.08687500e+02,
#          1.19339600e+03],
#        [ 1.00000000e+00,  2.88125000e+01, -1.12437500e+02,
#          1.58127502e+02],
#        [ 1.00000000e+00,  2.88125000e+01, -1.07437500e+02,
#          2.20583398e+03],
#        [ 1.00000000e+00,  2.63125000e+01, -1.12437500e+02,
#          1.34564606e+02],
#        [ 1.00000000e+00,  2.63125000e+01, -1.08687500e+02,
#          9.48212130e+01],
#        [ 1.00000000e+00,  2.63125000e+01, -1.07437500e+02,
#          1.47323206e+03],
#        [ 1.00000000e+00,  2.63125000e+01, -1.06187500e+02,
#          2.28963501e+03],
#        [ 1.00000000e+00,  3.13125000e+01, -1.11187500e+02,
#          1.23149805e+03],
#        [ 1.00000000e+00,  3.00625000e+01, -1.08687500e+02,
#          1.79106897e+03],
#        [ 1.00000000e+00,  3.00625000e+01, -1.14937500e+02,
#          6.57443420e+02],
#        [ 1.00000000e+00,  2.88125000e+01, -1.06187500e+02,
#          1.58490503e+03],
#        [ 1.00000000e+00,  2.88125000e+01, -1.09937500e+02,
#          6.19984680e+02],
#        [ 1.00000000e+00,  2.88125000e+01, -1.13687500e+02,
#          8.46978027e+02],
#        [ 1.00000000e+00,  2.88125000e+01, -1.11187500e+02,
#          1.34811996e+02],
#        [ 1.00000000e+00,  2.75625000e+01, -1.13687500e+02,
#          2.72799000e+01],
#        [ 1.00000000e+00,  2.75625000e+01, -1.12437500e+02,
#          3.68148987e+02],
#        [ 1.00000000e+00,  2.75625000e+01, -1.09937500e+02,
#          4.47640910e+01],
#        [ 1.00000000e+00,  2.75625000e+01, -1.08687500e+02,
#          1.26872095e+03],
#        [ 1.00000000e+00,  2.75625000e+01, -1.07437500e+02,
#          2.34393799e+03],
#        [ 1.00000000e+00,  2.75625000e+01, -1.06187500e+02,
#          1.75033704e+03],
#        [ 1.00000000e+00,  3.13125000e+01, -1.13687500e+02,
#          1.03325900e+01],
#        [ 1.00000000e+00,  3.00625000e+01, -1.09937500e+02,
#          1.00108801e+03],
#        [ 1.00000000e+00,  3.00625000e+01, -1.11187500e+02,
#          7.45982117e+02]])
