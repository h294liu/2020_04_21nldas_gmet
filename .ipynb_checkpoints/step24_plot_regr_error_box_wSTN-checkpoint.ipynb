# %%
#!/usr/bin/env python
# coding: utf-8

# This script is used to compare ensemble outputs with NLDAS data
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import pandas as pd
import xarray as xr
import datetime

#======================================================================================================
# main script
root_dir = '/glade/u/home/hongli/scratch/2020_04_21nldas_gmet'   
stn_grid_file = os.path.join(root_dir,'data/nldas_topo/conus_ens_grid_eighth.nc')
nldas_grid_file = os.path.join(root_dir,'data/nldas_topo/conus_ens_grid_eighth_deg_v1p1.nc')

stn_regr_dir = '/glade/u/home/hongli/scratch/2020_08_17stn_gmet/stn_gmet/gmet_regr_summary'
nldas_regr_dir = os.path.join(root_dir,'test_uniform_perturb')
test_folders = [d for d in os.listdir(nldas_regr_dir)]
test_folders = sorted(test_folders)

scenarios_ids = range(0,9)  
intervals =  range(10,2,-1) 
scenario_num = len(scenarios_ids)

time_format = '%Y-%m-%d'
plot_date_start = '2012-01-01' #'1979-01-01' #'2013-01-01'
plot_date_end = '2016-12-31' #'2019-12-31' #'2016-12-31'
plot_date_start_obj = datetime.datetime.strptime(plot_date_start, time_format)
plot_date_end_obj = datetime.datetime.strptime(plot_date_end, time_format)

dpi_value = 150
output_dir=os.path.join(root_dir, 'scripts/step24_plot_regr_error_box_wSTN')
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
# #======================================================================================================
# print('Read gridinfo mask')
# # get xy mask from gridinfo.nc
# f_stn_grid = xr.open_dataset(stn_grid_file)
# stn_mask_xy = f_stn_grid['mask'].values[:] # (y, x). 1 is valid. 0 is invalid.

# f_nldas_grid = xr.open_dataset(nldas_grid_file)
# nldas_mask_xy = f_nldas_grid['mask'].values[:] # (y, x). 1 is valid. 0 is invalid.

# # commonly available area
# mask_xy = (stn_mask_xy!=0) & (nldas_mask_xy!=0) 

# #======================================================================================================
# # read scenario regression results and save to dictionary
# print('Read nldas regression uncertainty')

# for k in range(scenario_num):
# # for k in range(7,9):

#     test_folder = test_folders[scenarios_ids[k]]
    
#     print(test_folder)
#     output_basename = os.path.join(nldas_regr_dir, test_folder, 
#                                    'gmet_regr_summary', 'regress_ts_')
#     fig_title= test_folder

#     print(' -- read spatial uncertainty')
#     # read regression uncertainty    
#     print('pcp_error')
#     f=xr.open_dataset(os.path.join(output_basename+'pcp_error.nc'))
#     pcp_error = f['pcp_error'].values[:]
#     time = f['time'].values[:]
#     time_regr = pd.to_datetime(time)

#     print('tmean_error_2')
#     f=xr.open_dataset(os.path.join(output_basename+'tmean_error_2.nc'))
#     tmean_error_2 = f['tmean_error_2'].values[:]

#     print('trange_error_2')
#     f=xr.open_dataset(os.path.join(output_basename+'trange_error_2.nc'))
#     trange_error_2 = f['trange_error_2'].values[:]
    
#     # define plot mask for nldas ensemble
#     mask_ens_t = (time_regr>=plot_date_start_obj) & (time_regr<=plot_date_end_obj)
    
#     print(' -- calculate temporal mean')
#     # caluclate time series mean(ny,nx)
#     pcp_error_mean = np.nanmean(pcp_error[mask_ens_t,:,:],axis=0)     
#     tmean_error_2_mean = np.nanmean(tmean_error_2[mask_ens_t,:,:],axis=0)
#     trange_error_2_mean = np.nanmean(trange_error_2[mask_ens_t,:,:],axis=0)
    
#     print(' -- extract unmasked values')
#     # extract unmasked values
#     pcp_error_mean=pcp_error_mean[mask_xy]    
#     tmean_error_2_mean=tmean_error_2_mean[mask_xy] 
#     trange_error_2_mean=trange_error_2_mean[mask_xy] 
    
#     # save to array
#     if k == 0:
#         grid_num = len(pcp_error_mean)
#         pcp_error_mean_arr = np.zeros((grid_num,scenario_num+1)) #one more column for station regr
#         tmean_error_2_mean_arr = np.zeros((grid_num,scenario_num+1)) 
#         trange_error_2_mean_arr = np.zeros((grid_num,scenario_num+1))
    
#     pcp_error_mean_arr[:,k] = pcp_error_mean
#     tmean_error_2_mean_arr[:,k] = tmean_error_2_mean 
#     trange_error_2_mean_arr[:,k] = trange_error_2_mean
    
#     del pcp_error_mean, tmean_error_2_mean, trange_error_2_mean
#     del pcp_error, tmean_error_2, trange_error_2  

# #======================================================================================================
# # read station regression results
# print('Read station regression uncertainty')
# print(' -- read spatial errors')
# output_basename = os.path.join(stn_regr_dir, 'regress_ts_')

# print('pcp_error')
# f=xr.open_dataset(os.path.join(output_basename+'pcp_error.nc'))
# stn_pcp_error = f['pcp_error'].values[:]
# time = f['time'].values[:]
# stn_time_regr = pd.to_datetime(time)

# print('tmean_error_2')
# f=xr.open_dataset(os.path.join(output_basename+'tmean_error_2.nc'))
# stn_tmean_error_2 = f['tmean_error_2'].values[:]

# print('trange_error_2')
# f=xr.open_dataset(os.path.join(output_basename+'trange_error_2.nc'))
# stn_trange_error_2 = f['trange_error_2'].values[:]

# # define plot mask for stn regr
# mask_stn_t = (stn_time_regr>=plot_date_start_obj) & (stn_time_regr<=plot_date_end_obj)

# print(' -- calculate temporal mean')
# # caluclate time series mean(ny,nx)
# stn_pcp_error_mean = np.nanmean(stn_pcp_error[mask_stn_t,:,:],axis=0)     
# stn_tmean_error_2_mean = np.nanmean(stn_tmean_error_2[mask_stn_t,:,:],axis=0)
# stn_trange_error_2_mean = np.nanmean(stn_trange_error_2[mask_stn_t,:,:],axis=0)

# print(' -- extract unmasked values')
# # extract unmasked values
# stn_pcp_error_mean=stn_pcp_error_mean[mask_xy]    
# stn_tmean_error_2_mean=stn_tmean_error_2_mean[mask_xy] 
# stn_trange_error_2_mean=stn_trange_error_2_mean[mask_xy] 

# pcp_error_mean_arr[:,-1] = stn_pcp_error_mean
# tmean_error_2_mean_arr[:,-1] = stn_tmean_error_2_mean 
# trange_error_2_mean_arr[:,-1] = stn_trange_error_2_mean

# del stn_pcp_error_mean, stn_tmean_error_2_mean, stn_trange_error_2_mean
# del stn_pcp_error, stn_tmean_error_2, stn_trange_error_2  
 
# #======================================================================================================    
# # save
# print('Save')
# var_list = ["Precp'", 'Tmean_2', 'Trange_2']

# nrow = len(var_list) # prcp, tmean, trange
# for i in range(nrow):
#         print(var_list[i])
        
#         # select data for each subplot
#         if i == 0:
#             data=pcp_error_mean_arr
#         elif i == 1:
#             data=tmean_error_2_mean_arr
#         elif i == 2:
#             data=trange_error_2_mean_arr
            
#         # save time-series mean uncertainty of all valid grids and all scenarios (once for all)
#         output_filename_txt = var_list[i]+'_regr_unc.txt'
#         np.savetxt(os.path.join(output_dir, output_filename_txt), data, delimiter=',',
#                     fmt='%f',header='Col is sample scenario. Row is the time-series mean of regr unc in flatten valid grids. The last col is for stn_regr.')

#======================================================================================================    
# # plot 
# print('Plot 1: without station')
# var_list = ["Precp'", 'Tmean_2', 'Trange_2'] #"Precp_2'", 
# title_list = ["Precipitation", 'Tmean', 'Trange']
# unit_list = ["$(mm/d)^{0.25}$", '($^\circ$C)', '($^\circ$C)']
# output_filename = 'step24_plot_regr_error_box.png'

# nrow = len(var_list) # prcp, tmean, tmin, tmax, trange
# ncol = 1 
# fig, ax = plt.subplots(nrow, ncol, figsize=(6.5,5.5))#, constrained_layout=True)

# for i in range(nrow):
#     print(var_list[i])

#     # select data for each subplot
#     if i == 0:
#         top=2
#     elif i == 1:
#         top=0.7
#     elif i == 2:
#         top=18
#     elif i == 3:
#         top=15

#     # load time-series mean of uncertainty 
#     output_filename_txt = var_list[i]+'_regr_unc.txt'
#     data = np.loadtxt(os.path.join(output_dir, output_filename_txt), delimiter=',', skiprows=1)

#     # boxplot
#     # reference: https://matplotlib.org/3.1.1/gallery/statistics/boxplot_demo.html
#     bp = ax[i].boxplot(data[:,0:-1], sym='o')#, labels=labels)
#     plt.setp(bp['boxes'], color='black')
#     plt.setp(bp['whiskers'], color='black',markersize=0.25)
#     plt.setp(bp['fliers'], color='red', marker='*',markersize=0.8)

#     # Add a horizontal grid to the plot, but make it very light in color
#     # so we can use it for reading data values but not be distracting
#     ax[i].yaxis.grid(True, linestyle='-', which='major', color='lightgrey',alpha=0.5)
#     ax[i].set_axisbelow(True)

#     # y_lim
# #         bottom=np.nanmin(data)-0.05*(np.nanmax(data)-np.nanmin(data))
# #         top=np.nanmax(data)*1.05
# #         ax[i].set_ylim(bottom=0, top=top)

#     # Due to the Y-axis scale being different across samples, it can be
#     # hard to compare differences in medians across the samples. Add upper
#     # X-axis tick labels with the sample medians to aid in comparison
#     # (just use two decimal places of precision)
#     pos = np.arange(scenario_num) 
#     medians = [(bp['medians'][k]).get_ydata()[0] for k in range(scenario_num)]
#     upper_labels = [str(np.round(s, 2)) for s in medians]
#     for tick, label in zip(range(scenario_num), ax[i].get_xticklabels()):
#         k = tick % 2
#         ax[i].text(pos[tick]+1.2, 0.9, upper_labels[tick],
#                  transform=ax[i].get_xaxis_transform(),
#                  horizontalalignment='center', size='x-small',
#                  fontstyle='italic', color='b') #pos[tick], 1.02

#     # set y-axis label
#     y_lable = r'Residual $\epsilon$ ' + unit_list[i] #'Regression uncertainty'
#     ax[i].set_ylabel(y_lable, fontsize='x-small')
#     if i == nrow-1:
#         ax[i].set_xlabel('Sampling Scenario', fontsize='x-small')

#     x_ticks = [str(x) for x in range(1,10)]
# #     x_ticks.append('stn_regr')
#     ax[i].set_xticklabels(x_ticks)
#     ax[i].tick_params(axis='both', direction='out',labelsize = 'x-small',
#                       length=1.5, width=0.5, pad=1.5)       
#     # title
#     alpha = chr(ord('a') + i)
#     ax[i].set_title('('+alpha+') '+title_list[i], pad=3, 
#                     fontsize='x-small', fontweight='semibold') #pad=9
        
# # save plot
# fig.tight_layout(pad=0.1, h_pad=0.5) #h_pad=0.7
# fig.savefig(os.path.join(output_dir, output_filename), dpi=dpi_value, bbox_inches = 'tight', pad_inches = 0.05)
# plt.close(fig)

#======================================================================================================    
# plot 
print('Plot 2: with station')
var_list = ["Precp'", 'Tmean_2', 'Trange_2'] #"Precp_2'", 
title_list = ["Precip", 'Tmean', 'DTR']

ylabel_list = ['$\^\sigma_{Precip}$','$\^\sigma_{Tmean}$','$\^\sigma_{DTR}$']
unit_list = ["$(mm/d)^{0.25}$", '($^\circ$C)', '($^\circ$C)']
output_filename = 'step24_plot_regr_error_box_wSTN.png'

nrow = len(var_list) # prcp, tmean, tmin, tmax, trange
ncol = 1 
fig, ax = plt.subplots(nrow, ncol, figsize=(6.5,5.5))#, constrained_layout=True)

for i in range(nrow):
    print(var_list[i])

    # select data for each subplot
    if i == 0:
        top=2
    elif i == 1:
        top=5
    elif i == 2:
        top=18

    # load time-series mean of uncertainty 
    output_filename_txt = var_list[i]+'_regr_unc.txt'
    data = np.loadtxt(os.path.join(output_dir, output_filename_txt), delimiter=',', skiprows=1)

    # boxplot
    # reference: https://matplotlib.org/3.1.1/gallery/statistics/boxplot_demo.html
    # reference: https://stackoverflow.com/questions/43342564/flier-colors-in-boxplot-with-matplotlib
    flierprops = dict(marker='o', markerfacecolor='none', markersize=0.5,
                  linestyle='none', markeredgecolor='grey')

    bp = ax[i].boxplot(data, flierprops=flierprops)#, labels=labels)
    plt.setp(bp['boxes'], color='black')
    plt.setp(bp['whiskers'], color='black',marker='o',markersize=0.2)
#     plt.setp(bp['fliers'], markersize=0.5)#color='red', marker='+',

    # Add a horizontal grid to the plot, but make it very light in color
    # so we can use it for reading data values but not be distracting
    ax[i].yaxis.grid(True, linestyle='-', which='major', color='lightgrey',alpha=0.5)
    ax[i].set_axisbelow(True)

    # y_lim
#     bottom=np.nanmin(data)-0.05*(np.nanmax(data)-np.nanmin(data))
#     top=np.nanpercentile(data,99)
    if i == 1:
        ax[i].set_ylim(top=top)

    # Due to the Y-axis scale being different across samples, it can be
    # hard to compare differences in medians across the samples. Add upper
    # X-axis tick labels with the sample medians to aid in comparison
    # (just use two decimal places of precision)
    pos = np.arange(scenario_num+1) 
    medians = [(bp['medians'][k]).get_ydata()[0] for k in range(scenario_num+1)]
    upper_labels = [str(np.round(s, 2)) for s in medians]
    for tick, label in zip(range(scenario_num+1), ax[i].get_xticklabels()):
        k = tick % 2
        ax[i].text(pos[tick]+1.2, 0.9, upper_labels[tick],
                 transform=ax[i].get_xaxis_transform(),
                 horizontalalignment='center', size='x-small',
                 fontstyle='italic', color='b') 

    # set y-axis label
#     y_lable = r'Residual $\epsilon$ ' + unit_list[i] #'Regression uncertainty'
    y_lable = ylabel_list[i] +' '+ unit_list[i] #'Regression uncertainty'
    ax[i].set_ylabel(y_lable, fontsize='small')
    if i == nrow-1:
        ax[i].set_xlabel('Sampling Scenario', fontsize='x-small')

    x_ticks = [str(x) for x in range(1,10)]
    x_ticks.append('N15')
    ax[i].set_xticklabels(x_ticks)
    ax[i].tick_params(axis='both', direction='out',labelsize = 'x-small',
                      length=1.5, width=0.5, pad=1.5)       
    # title
    alpha = chr(ord('a') + i)
    ax[i].set_title('('+alpha+') '+title_list[i], pad=3, 
                    fontsize='x-small', fontweight='semibold') #pad=9
        
# save plot
fig.tight_layout(pad=0.1, h_pad=0.5) #h_pad=0.7
fig.savefig(os.path.join(output_dir, output_filename), dpi=dpi_value, bbox_inches = 'tight', pad_inches = 0.05)
plt.close(fig)

print('Done')
# Out:
# Read gridinfo mask
# Read nldas regression uncertainty
# 00814grids
#  -- read spatial uncertainty
# pcp_error
# tmean_error_2
# trange_error_2
#  -- calculate temporal mean
# <ipython-input-1-e91f2ffac2d4>:86: RuntimeWarning: Mean of empty slice
#   pcp_error_mean = np.nanmean(pcp_error[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:87: RuntimeWarning: Mean of empty slice
#   tmean_error_2_mean = np.nanmean(tmean_error_2[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:88: RuntimeWarning: Mean of empty slice
#   trange_error_2_mean = np.nanmean(trange_error_2[mask_ens_t,:,:],axis=0)
#  -- extract unmasked values
# 00977grids
#  -- read spatial uncertainty
# pcp_error
# tmean_error_2
# trange_error_2
#  -- calculate temporal mean
# <ipython-input-1-e91f2ffac2d4>:86: RuntimeWarning: Mean of empty slice
#   pcp_error_mean = np.nanmean(pcp_error[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:87: RuntimeWarning: Mean of empty slice
#   tmean_error_2_mean = np.nanmean(tmean_error_2[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:88: RuntimeWarning: Mean of empty slice
#   trange_error_2_mean = np.nanmean(trange_error_2[mask_ens_t,:,:],axis=0)
#  -- extract unmasked values
# 01228grids
#  -- read spatial uncertainty
# pcp_error
# tmean_error_2
# trange_error_2
#  -- calculate temporal mean
# <ipython-input-1-e91f2ffac2d4>:86: RuntimeWarning: Mean of empty slice
#   pcp_error_mean = np.nanmean(pcp_error[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:87: RuntimeWarning: Mean of empty slice
#   tmean_error_2_mean = np.nanmean(tmean_error_2[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:88: RuntimeWarning: Mean of empty slice
#   trange_error_2_mean = np.nanmean(trange_error_2[mask_ens_t,:,:],axis=0)
#  -- extract unmasked values
# 01619grids
#  -- read spatial uncertainty
# pcp_error
# tmean_error_2
# trange_error_2
#  -- calculate temporal mean
# <ipython-input-1-e91f2ffac2d4>:86: RuntimeWarning: Mean of empty slice
#   pcp_error_mean = np.nanmean(pcp_error[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:87: RuntimeWarning: Mean of empty slice
#   tmean_error_2_mean = np.nanmean(tmean_error_2[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:88: RuntimeWarning: Mean of empty slice
#   trange_error_2_mean = np.nanmean(trange_error_2[mask_ens_t,:,:],axis=0)
#  -- extract unmasked values
# 02267grids
#  -- read spatial uncertainty
# pcp_error
# tmean_error_2
# trange_error_2
#  -- calculate temporal mean
# <ipython-input-1-e91f2ffac2d4>:86: RuntimeWarning: Mean of empty slice
#   pcp_error_mean = np.nanmean(pcp_error[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:87: RuntimeWarning: Mean of empty slice
#   tmean_error_2_mean = np.nanmean(tmean_error_2[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:88: RuntimeWarning: Mean of empty slice
#   trange_error_2_mean = np.nanmean(trange_error_2[mask_ens_t,:,:],axis=0)
#  -- extract unmasked values
# 03199grids
#  -- read spatial uncertainty
# pcp_error
# tmean_error_2
# trange_error_2
#  -- calculate temporal mean
# <ipython-input-1-e91f2ffac2d4>:86: RuntimeWarning: Mean of empty slice
#   pcp_error_mean = np.nanmean(pcp_error[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:87: RuntimeWarning: Mean of empty slice
#   tmean_error_2_mean = np.nanmean(tmean_error_2[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:88: RuntimeWarning: Mean of empty slice
#   trange_error_2_mean = np.nanmean(trange_error_2[mask_ens_t,:,:],axis=0)
#  -- extract unmasked values
# 04975grids
#  -- read spatial uncertainty
# pcp_error
# tmean_error_2
# trange_error_2
#  -- calculate temporal mean
# <ipython-input-1-e91f2ffac2d4>:86: RuntimeWarning: Mean of empty slice
#   pcp_error_mean = np.nanmean(pcp_error[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:87: RuntimeWarning: Mean of empty slice
#   tmean_error_2_mean = np.nanmean(tmean_error_2[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:88: RuntimeWarning: Mean of empty slice
#   trange_error_2_mean = np.nanmean(trange_error_2[mask_ens_t,:,:],axis=0)
#  -- extract unmasked values
# 08925grids
#  -- read spatial uncertainty
# pcp_error
# tmean_error_2
# trange_error_2
#  -- calculate temporal mean
# <ipython-input-1-e91f2ffac2d4>:86: RuntimeWarning: Mean of empty slice
#   pcp_error_mean = np.nanmean(pcp_error[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:87: RuntimeWarning: Mean of empty slice
#   tmean_error_2_mean = np.nanmean(tmean_error_2[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:88: RuntimeWarning: Mean of empty slice
#   trange_error_2_mean = np.nanmean(trange_error_2[mask_ens_t,:,:],axis=0)
#  -- extract unmasked values
# 18199grids
#  -- read spatial uncertainty
# pcp_error
# tmean_error_2
# trange_error_2
#  -- calculate temporal mean
# <ipython-input-1-e91f2ffac2d4>:86: RuntimeWarning: Mean of empty slice
#   pcp_error_mean = np.nanmean(pcp_error[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:87: RuntimeWarning: Mean of empty slice
#   tmean_error_2_mean = np.nanmean(tmean_error_2[mask_ens_t,:,:],axis=0)
# <ipython-input-1-e91f2ffac2d4>:88: RuntimeWarning: Mean of empty slice
#   trange_error_2_mean = np.nanmean(trange_error_2[mask_ens_t,:,:],axis=0)
#  -- extract unmasked values
# Read station regression uncertainty
#  -- read spatial errors
# pcp_error
# tmean_error_2
# trange_error_2
#  -- calculate temporal mean
#  -- extract unmasked values
# Save
# Precp'
# Tmean_2
# Trange_2
# Plot 2: with station
# Precp'
# Tmean_2
# Trange_2
# Done

# %%
pcp_error_mean_arr[0:10,:], stn_pcp_error_mean[0:10]
# Out:
# (array([[0.40961308, 0.37816416, 0.34724058, 0.30261245, 0.22783741,
#          0.20604604, 0.15766092, 0.14756014, 0.10817337, 0.41896909],
#         [0.40974644, 0.38053833, 0.34919949, 0.31607838, 0.24208798,
#          0.20727783, 0.16156353, 0.14914181, 0.10955001, 0.42033763],
#         [0.41304575, 0.38342077, 0.35120453, 0.32894216, 0.25263958,
#          0.20957106, 0.16911027, 0.1503006 , 0.11055587, 0.42168174],
#         [0.41955928, 0.38556515, 0.35326037, 0.33141089, 0.25128201,
#          0.21692737, 0.17323296, 0.15114161, 0.11112724, 0.42251969],
#         [0.42548411, 0.3919486 , 0.35537108, 0.3405954 , 0.25703377,
#          0.2221045 , 0.17681471, 0.14976957, 0.11583694, 0.42288409],
#         [0.42794077, 0.39874106, 0.35639956, 0.34578002, 0.26487006,
#          0.2245549 , 0.17396703, 0.14893067, 0.12013813, 0.42528968],
#         [0.43224378, 0.40443667, 0.35981293, 0.34978752, 0.27238788,
#          0.22386922, 0.18248628, 0.14854961, 0.12411963, 0.42747547],
#         [0.43857391, 0.40904198, 0.36553253, 0.35368515, 0.28329971,
#          0.22593844, 0.18460445, 0.14784552, 0.1264748 , 0.43023024],
#         [0.43878992, 0.4173579 , 0.36840062, 0.35748253, 0.28802245,
#          0.24170582, 0.18720918, 0.14726684, 0.12762371, 0.43225565],
#         [0.43905213, 0.42351284, 0.37815484, 0.3605816 , 0.30477585,
#          0.26256639, 0.20468386, 0.15331783, 0.12799694, 0.43427876]]),
#  array([0.41896909, 0.42033763, 0.42168174, 0.42251969, 0.42288409,
#         0.42528968, 0.42747547, 0.43023024, 0.43225565, 0.43427876]))

# %%
pcp_error_mean_arr[0:10,8:]
# Out:
# array([[0.10817337, 0.10817337],
#        [0.10955001, 0.10955001],
#        [0.11055587, 0.11055587],
#        [0.11112724, 0.11112724],
#        [0.11583694, 0.11583694],
#        [0.12013813, 0.12013813],
#        [0.12411963, 0.12411963],
#        [0.1264748 , 0.1264748 ],
#        [0.12762371, 0.12762371],
#        [0.12799694, 0.12799694]])

# %%
scenario_num
# Out:
# 9
